# %%
print("R is working")
# Out:
# [1] "R is working"

# %%
uploaded<-file.choose()
# Out:
# Error in file.choose(): file choice cancelled
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "file choice cancelled", base::quote(file.choose()))

# %%
if (!require("data.table")install,packages("data.table"))
# Out:
# Error in parse(text = input): <text>:1:27: unexpected symbol
# 1: if (!require("data.table")install
#                               ^
# Traceback:

# %%
df<-read.csv("accident_prediction_india.csv")
head(df)
# Out:
#   State.Name        City.Name Year Month    Day.of.Week Time.of.Day
# 1 Jammu and Kashmir Unknown   2021 May      Monday      1:46
# 2 Uttar Pradesh     Lucknow   2018 January  Wednesday   21:30
# 3 Chhattisgarh      Unknown   2023 May      Wednesday   5:37
# 4 Uttar Pradesh     Lucknow   2020 June     Saturday    0:31
# 5 Sikkim            Unknown   2021 August   Thursday    11:21
# 6 Meghalaya         Unknown   2020 November Tuesday     8:4
#   Accident.Severity Number.of.Vehicles.Involved Vehicle.Type.Involved
# 1 Serious           5                           Cycle
# 2 Minor             5                           Truck
# 3 Minor             5                           Pedestrian
# 4 Minor             3                           Bus
# 5 Minor             5                           Cycle
# 6 Serious           1                           Truck
#   Number.of.Casualties ⋯ Road.Type        Road.Condition
# 1  0                   ⋯ National Highway Wet
# ...

# %%
table_data<-table(df$Weather.Conditions,df$Accident.Severity)
print(table_data)
chisq.test(table_data)
# Out:
#
#          Fatal Minor Serious
#   Clear    190   202     182
#   Foggy    195   174     207
#   Hazy     200   203     205
#   Rainy    197   224     210
#   Stormy   203   231     177
# 	Pearson's Chi-squared test
#
# data:  table_data
# X-squared = 11.098, df = 8, p-value = 0.1962
